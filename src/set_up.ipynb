# %%
# %sql
SHOW EXTERNAL LOCATIONS;
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %sql
SHOW EXTERNAL LOCATIONS;
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %sql

# CREATE EXTERNAL LOCATION IF NOT EXISTS stream_loc
# URL 's3://databricks-streaming-data-demo/'
# WITH (STORAGE CREDENTIAL credential_dbs);

# CREATE EXTERNAL LOCATION IF NOT EXISTS batch_loc
# URL 's3://databricks-batch-data-demo/'
# WITH (STORAGE CREDENTIAL credential_dbs);
# CREATE EXTERNAL LOCATION IF NOT EXISTS mgmt_loc
# URL 's3://databrick-lambda-arcchitechture/' 
# WITH (STORAGE CREDENTIAL credential_dbs);

# %%
# %sql
CREATE CATALOG IF NOT EXISTS dev
 LOCATION 's3://databrick-lambda-arcchitechture';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS dev.bronze_stream ; 
# MANAGED LOCATION 's3://databricks-streaming-data-demo/delta/bronze/';

CREATE SCHEMA IF NOT EXISTS dev.silver_stream ;
# MANAGED LOCATION 's3://databricks-streaming-data-demo/delta/silver/';


CREATE SCHEMA IF NOT EXISTS dev.gold_stream ; 
# MANAGED LOCATION 's3://databricks-streaming-data-demo/delta/gold/';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS dev.bronze_batch
# MANAGED LOCATION 's3://databricks-batch-data-demo/delta/bronze/';

CREATE SCHEMA IF NOT EXISTS dev.silver_batch
# MANAGED LOCATION 's3://databricks-batch-data-demo/delta/silver/';

CREATE SCHEMA IF NOT EXISTS dev.gold_batch
# MANAGED LOCATION 's3://databricks-batch-data-demo/delta/gold/';

# %%
# %sql
CREATE VOLUME IF NOT EXISTS dev.bronze_stream.checkpoint;
CREATE VOLUME IF NOT EXISTS dev.silver_stream.checkpoint;
CREATE VOLUME IF NOT EXISTS dev.bronze_batch.checkpoint;
CREATE VOLUME IF NOT EXISTS dev.silver_batch.checkpoint;
CREATE VOLUME IF NOT EXISTS dev.gold_batch.checkpoint;
CREATE VOLUME IF NOT EXISTS dev.gold_stream.checkpoint;

# %%
# %sql

CREATE EXTERNAL LOCATION IF NOT EXISTS stream_loc
URL 's3://databricks-streaming-data-demo/'
WITH (STORAGE CREDENTIAL credential_dbs);

CREATE EXTERNAL LOCATION IF NOT EXISTS batch_loc
URL 's3://databricks-batch-data-demo/'
WITH (STORAGE CREDENTIAL credential_dbs);
CREATE EXTERNAL LOCATION IF NOT EXISTS mgmt_loc
URL 's3://databrick-lambda-arcchitechture/' 
WITH (STORAGE CREDENTIAL credential_dbs);

# %%
# %sql
CREATE CATALOG IF NOT EXISTS dev
 LOCATION 's3://databrick-lambda-arcchitechture';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS dev.bronze_stream
MANAGED LOCATION 's3://databricks-streaming-data-demo/delta/bronze/';

CREATE SCHEMA IF NOT EXISTS dev.silver_stream
MANAGED LOCATION 's3://databricks-streaming-data-demo/delta/silver/';


CREATE SCHEMA IF NOT EXISTS dev.gold_stream
MANAGED LOCATION 's3://databricks-streaming-data-demo/delta/gold/';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS dev.bronze_batch
MANAGED LOCATION 's3://databricks-batch-data-demo/delta/bronze/';

CREATE SCHEMA IF NOT EXISTS dev.silver_batch
MANAGED LOCATION 's3://databricks-batch-data-demo/delta/silver/';

CREATE SCHEMA IF NOT EXISTS dev.gold_batch
MANAGED LOCATION 's3://databricks-batch-data-demo/delta/gold/';

# %%
# %sql
CREATE VOLUME IF NOT EXISTS dev.bronze_stream.checkpoint;
CREATE VOLUME IF NOT EXISTS dev.silver_stream.checkpoint;
CREATE VOLUME IF NOT EXISTS dev.bronze_batch.checkpoint;
CREATE VOLUME IF NOT EXISTS dev.silver_batch.checkpoint;
CREATE VOLUME IF NOT EXISTS dev.gold_batch.checkpoint;
CREATE VOLUME IF NOT EXISTS dev.gold_stream.checkpoint;
