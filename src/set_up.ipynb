# %%
# %sql

CREATE CATALOG IF NOT EXISTS dev;


CREATE SCHEMA IF NOT EXISTS dev.bronze;
CREATE SCHEMA IF NOT EXISTS dev.silver;
CREATE SCHEMA IF NOT EXISTS dev.gold;
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %sql
# CREATE TABLE dev.bronze.batch_bronze USING DELTA ;
# CREATE TABLE dev.silver.batch_bronze USING DELTA ; 
# CREATE TABLE dev.gold.batch_bronze USING DELTA ;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS dev.bronze.checkpoint  ;
CREATE VOLUME IF NOT EXISTS dev.silver.checkpoint  ; 
CREATE VOLUME IF NOT EXISTS dev.gold.checkpoint  ;
